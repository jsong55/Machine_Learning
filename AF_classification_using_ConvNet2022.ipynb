# %% [markdown]
# <a href="https://colab.research.google.com/github/jsong55/Machine_Learning/blob/master/AF_classification_using_ConvNet2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os
import random
import tensorflow as tf
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Activation
from tensorflow.keras import Sequential, layers
from tensorflow import keras
from tensorflow.keras.layers.experimental import preprocessing
import datetime
import tensorflow_hub as hub

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget https://raw.githubusercontent.com/jsong55/Machine_Learning/master/TF_functions.py
from TF_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir, view_random_image
# Out:
# --2022-10-24 02:53:06--  https://raw.githubusercontent.com/jsong55/Machine_Learning/master/TF_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10747 (10K) [text/plain]
# Saving to: ‘TF_functions.py’
#
# TF_functions.py     100%[===================>]  10.50K  --.-KB/s    in 0s
#
# 2022-10-24 02:53:06 (81.5 MB/s) - ‘TF_functions.py’ saved [10747/10747]

# %% [markdown]
# ## Acquire the data

# %%
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/python_torturial/NW_image_quality_50tests_rgb_revserved.zip","r")
zip_ref.extractall()
zip_ref.close()

# Setup the train and test directories
train_dir = "NW_image_quality_50tests_rgb_revserved/train/"
test_dir = "NW_image_quality_50tests_rgb_revserved/test/"

# visualize
data_dir = pathlib.Path(train_dir)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))

img = view_random_image(target_dir=train_dir,
              target_class=random.choice(class_names))
# Out:
# image shape: (150, 150, 3)

# %%
class_names
# Out:
# array(['1', '2', '3', '4', '5'], dtype='<U1')

# %%
IMAGE_SIZE = (150,150)
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory=train_dir,
                                        image_size=IMAGE_SIZE,
                                        label_mode="categorical",
                                        batch_size=32,
                                        shuffle=True)

test_data = tf.keras.preprocessing.image_dataset_from_directory(directory=test_dir,
                                  image_size=IMAGE_SIZE,
                                  label_mode="categorical",
                                  batch_size=32)
# Out:
# Found 2640 files belonging to 5 classes.
# Found 1200 files belonging to 5 classes.

# %% [markdown]
# ## Get the Base model: ConvNet

# %%
# 1. Create base model with tf.keras.applications
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
# Check the layers in our base model
#for layer_number, layer in enumerate(base_model.layers):
#  print(layer_number, layer.name)

# The model contains a noramlization and rescaling layer

# 2. Free the base model (the underlying pre-trained patterns aren't updated during training)
base_model.trainable = False

# 3. Create inputs into our model
inputs = tf.keras.layers.Input(shape=(150,150,3),name="input_layer")

# 4. If using a model like ResNet50V2, you will need to noramlize inputs
# x = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)

# 5. Pass the inputs to the base_model
x = base_model(inputs)
print(f"shape after passing inputs through base model: {x.shape}")

# 6. Average pool the outputs of the base model (aggregate all the most important information, reduce number of computations)
x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

# 7. Create the output activation layer
outputs = tf.keras.layers.Dense(5,activation="softmax",name="output_layer")(x)

# 8. Combine the inputs with the outputs into a model
model_0 = tf.keras.Model(inputs, outputs)

# 9. Compile the model
model_0.compile(loss="categorical_crossentropy",
        optimizer = Adam(),
        metrics=["accuracy"])

# 10. Fit the model and save the history
history_0 = model_0.fit(train_data,
                  epochs=50,
                  steps_per_epoch=len(train_data),
                  validation_data=test_data,
                  validation_steps=int(0.1*len(test_data)),
                  callbacks=[create_tensorboard_callback(dir_name="ConvNet",
                                      experiment_name="ConvNet_test1")])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# shape after passing inputs through base model: (None, 4, 4, 1280)
# Shape after GlobalAveragePooling2D: (None, 1280)
# Saving TensorBoard log files to: ConvNet/ConvNet_test1/20221024-025355
# Epoch 1/50
# 83/83 [==============================] - 17s 59ms/step - loss: 1.3343 - accuracy: 0.3795 - val_loss: 1.1017 - val_accuracy: 0.4896
# Epoch 2/50
# 83/83 [==============================] - 3s 39ms/step - loss: 1.1401 - accuracy: 0.4936 - val_loss: 1.0814 - val_accuracy: 0.5000
# Epoch 3/50
# 83/83 [==============================] - 3s 38ms/step - loss: 1.0816 - accuracy: 0.5072 - val_loss: 0.9606 - val_accuracy: 0.5417
# Epoch 4/50
# 83/83 [==============================] - 3s 39ms/step - loss: 1.0348 - accuracy: 0.5345 - val_loss: 1.0580 - val_accuracy: 0.5104
# Epoch 5/50
# 83/83 [==============================] - 3s 39ms/step - loss: 1.0007 - accuracy: 0.5595 - val_loss: 0.9059 - val_accuracy: 0.5938
# Epoch 6/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.9729 - accuracy: 0.5848 - val_loss: 0.9699 - val_accuracy: 0.5000
# Epoch 7/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.9529 - accuracy: 0.5754 - val_loss: 0.9657 - val_accuracy: 0.5312
# Epoch 8/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.9339 - accuracy: 0.5981 - val_loss: 0.9447 - val_accuracy: 0.5729
# Epoch 9/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.9190 - accuracy: 0.5939 - val_loss: 0.9749 - val_accuracy: 0.5521
# Epoch 10/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.9116 - accuracy: 0.6011 - val_loss: 1.0587 - val_accuracy: 0.5625
# Epoch 11/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.8944 - accuracy: 0.6087 - val_loss: 0.9675 - val_accuracy: 0.5312
# Epoch 12/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.8743 - accuracy: 0.6220 - val_loss: 1.1139 - val_accuracy: 0.4688
# Epoch 13/50
# 83/83 [==============================] - 4s 47ms/step - loss: 0.8667 - accuracy: 0.6409 - val_loss: 1.0838 - val_accuracy: 0.5104
# Epoch 14/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.8524 - accuracy: 0.6337 - val_loss: 1.0868 - val_accuracy: 0.4583
# Epoch 15/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.8585 - accuracy: 0.6352 - val_loss: 1.0316 - val_accuracy: 0.4688
# Epoch 16/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.8355 - accuracy: 0.6413 - val_loss: 1.0096 - val_accuracy: 0.4688
# Epoch 17/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.8264 - accuracy: 0.6492 - val_loss: 0.8821 - val_accuracy: 0.5729
# Epoch 18/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.8218 - accuracy: 0.6432 - val_loss: 1.0203 - val_accuracy: 0.5208
# Epoch 19/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.8141 - accuracy: 0.6519 - val_loss: 1.1992 - val_accuracy: 0.4375
# Epoch 20/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.8096 - accuracy: 0.6523 - val_loss: 1.0582 - val_accuracy: 0.5521
# Epoch 21/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7925 - accuracy: 0.6689 - val_loss: 1.0186 - val_accuracy: 0.4583
# Epoch 22/50
# 83/83 [==============================] - 4s 41ms/step - loss: 0.7899 - accuracy: 0.6754 - val_loss: 0.9008 - val_accuracy: 0.5208
# Epoch 23/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7820 - accuracy: 0.6674 - val_loss: 1.0523 - val_accuracy: 0.5000
# Epoch 24/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7981 - accuracy: 0.6595 - val_loss: 1.0904 - val_accuracy: 0.5521
# Epoch 25/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7681 - accuracy: 0.6886 - val_loss: 0.9694 - val_accuracy: 0.5208
# Epoch 26/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7751 - accuracy: 0.6845 - val_loss: 1.0182 - val_accuracy: 0.5104
# Epoch 27/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7609 - accuracy: 0.6848 - val_loss: 1.0470 - val_accuracy: 0.5729
# Epoch 28/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7678 - accuracy: 0.6742 - val_loss: 0.9839 - val_accuracy: 0.4792
# Epoch 29/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7600 - accuracy: 0.6928 - val_loss: 1.0162 - val_accuracy: 0.5208
# Epoch 30/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7546 - accuracy: 0.6875 - val_loss: 1.2762 - val_accuracy: 0.5104
# Epoch 31/50
# 83/83 [==============================] - 3s 38ms/step - loss: 0.7407 - accuracy: 0.6939 - val_loss: 0.9929 - val_accuracy: 0.5833
# Epoch 32/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7371 - accuracy: 0.7045 - val_loss: 1.1275 - val_accuracy: 0.5312
# Epoch 33/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7360 - accuracy: 0.6932 - val_loss: 1.0242 - val_accuracy: 0.4792
# Epoch 34/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7307 - accuracy: 0.6973 - val_loss: 1.0804 - val_accuracy: 0.5104
# Epoch 35/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7226 - accuracy: 0.7045 - val_loss: 1.0744 - val_accuracy: 0.5417
# Epoch 36/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7331 - accuracy: 0.6932 - val_loss: 1.0992 - val_accuracy: 0.5000
# Epoch 37/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7241 - accuracy: 0.7045 - val_loss: 0.9489 - val_accuracy: 0.5104
# Epoch 38/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7175 - accuracy: 0.7008 - val_loss: 1.0266 - val_accuracy: 0.5625
# Epoch 39/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.7102 - accuracy: 0.7053 - val_loss: 0.8266 - val_accuracy: 0.6354
# Epoch 40/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7154 - accuracy: 0.7098 - val_loss: 0.9525 - val_accuracy: 0.5833
# Epoch 41/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7110 - accuracy: 0.7114 - val_loss: 0.9584 - val_accuracy: 0.5729
# Epoch 42/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.6988 - accuracy: 0.7163 - val_loss: 1.1920 - val_accuracy: 0.5000
# Epoch 43/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.6941 - accuracy: 0.7186 - val_loss: 1.0751 - val_accuracy: 0.5104
# Epoch 44/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.6889 - accuracy: 0.7167 - val_loss: 1.2489 - val_accuracy: 0.5208
# Epoch 45/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.6990 - accuracy: 0.7095 - val_loss: 1.1082 - val_accuracy: 0.5938
# Epoch 46/50
# 83/83 [==============================] - 3s 39ms/step - loss: 0.6961 - accuracy: 0.7144 - val_loss: 1.0698 - val_accuracy: 0.5625
# Epoch 47/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.6875 - accuracy: 0.7246 - val_loss: 1.1545 - val_accuracy: 0.5625
# Epoch 48/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.6798 - accuracy: 0.7220 - val_loss: 1.2188 - val_accuracy: 0.4896
# Epoch 49/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.7013 - accuracy: 0.6973 - val_loss: 1.0338 - val_accuracy: 0.5312
# Epoch 50/50
# 83/83 [==============================] - 3s 40ms/step - loss: 0.6814 - accuracy: 0.7197 - val_loss: 1.0712 - val_accuracy: 0.5729

# %%
model_0.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling_laye  (None, 1280)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 5)                 6405
#
# =================================================================
# Total params: 4,055,976
# Trainable params: 6,405
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
plot_loss_curves(history_0)

# %%
results_0 = model_0.evaluate(test_data)
results_0
# Out:
# 38/38 [==============================] - 2s 46ms/step - loss: 0.9563 - accuracy: 0.5433
# [0.956339418888092, 0.5433333516120911]
